# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd 

survey_data = pd.read_csv("/home/khaijones/Data-Camp/Introduction to Data Vizualization with Seaborn/young-people-survey-responses.csv")

survey_data.head()
# Out:
#    Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0           0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1           1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2           2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
# 3           3    5.0     2.0     5.0      4.0          4.0   1.0      5.0
# 4           4    5.0     2.0     5.0      3.0          2.0   1.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances   Age  Siblings  \
# 0         3.0              4.0  few hours a day       3.0  20.0       1.0
# 1         2.0              2.0  few hours a day       3.0  19.0       2.0
# 2         5.0              3.0  few hours a day       2.0  20.0       2.0
# 3         5.0              2.0  most of the day       2.0  22.0       1.0
# 4         3.0              3.0  few hours a day       4.0  20.0       1.0
#
#    Gender Village - town
# 0  female        village
# ...

# %%
sns.catplot(x="how_masculine", 
                         data=masculinity_data,
                          kind="count")

plt.show()

# %%
category_order = ["No answer", 
                                  "Not at all",
                                  "Not Very", 
                                  "Somewhat",
                                  "Very"] 

sns.catplot(x="how_masculine", 
                         data=masculinity_data,
                          kind="count",
                           order=category_order)

# %%
sns.catplot(x="how_masculine", 
                         data=masculinity_data,
                         kind="bar",
                         order=category_order)

# %%
sns.catplot(x="how_masculine", 
                         data=masculinity_data,
                         kind="bar",
                         order=category_order,
                         ci=None )

# %%
# Create count plot of internet usage
sns.catplot(x="Internet usage",
            data=survey_data,
            kind="count")


# Show plot
plt.show()

# %%
# Create count plot of internet usage
sns.catplot(y="Internet usage",
            data=survey_data,
            kind="count")


# Show plot
plt.show()

# %%
# Separate into column subplots based on age category
sns.catplot(y="Internet usage", data=survey_data,
            kind="count", 
            col="Age")

# Show plot
plt.show()

# %%
sns.catplot(x="Gender", y="Mathematics", 
                    data=survey_data, 
                    kind="bar")

plt.show()

# %%
g = sns.catplot(x="Gender", y="Mathematics", 
                    data=survey_data, 
                    kind="box",
                    whis=[5, 95])

plt.show()

# %%
sns.catplot(x="age",
                    y="masculinity_important", 
                    data=masculinity_data, 
                    hue="feel_masculine",
                    kind="point",
                    estimator=median,
                    capsize=0.2,
                   join=False)
plt.show()
